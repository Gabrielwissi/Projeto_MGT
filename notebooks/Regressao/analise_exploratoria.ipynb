# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import pandas as pd
from automl import eda
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../../dataset/raw/housing.csv')
dados = pd.DataFrame(df)

# %%
analise = eda(dados, categoria = 'Supervisionado', tipo = 'Regressão', target_col = 'MEDV', modo = 'Estático')
# Out:
# Análise exploratória
#
# Alvo: MEDV
#
# 3 colunas numéricas
# ['RM', 'LSTAT', 'PTRATIO']
#
# 0 colunas categóricas
# []
#
# Valores nulos: 0 (0.00%)
#
# Estatísticas Descritivas de MEDV
#
# count        489.00
# mean      454342.94
# std       165340.28
# min       105000.00
# 25%       350700.00
# 50%       438900.00
# 75%       518700.00
# max      1024800.00
# Name: MEDV, dtype: float64
#
# --------------------------------------------------
# Resumo e Análise das Variáveis Numéricas
#
# Variável RM
#
# count    489.000000
# mean       6.240288
# std        0.643650
# min        3.561000
# 25%        5.880000
# 50%        6.185000
# 75%        6.575000
# max        8.398000
#
# Valores nulos: 0 (0.00%)
#
# --------------------------------------------------
# Variável LSTAT
#
# count    489.000000
# mean      12.939632
# std        7.081990
# min        1.980000
# 25%        7.370000
# 50%       11.690000
# 75%       17.120000
# max       37.970000
#
# Valores nulos: 0 (0.00%)
#
# ...
