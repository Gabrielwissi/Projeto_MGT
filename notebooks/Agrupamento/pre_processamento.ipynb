# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import pandas as pd
from automl import treinamento, otimizar, relatorio, salvar
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../../dataset/raw/Mall_Customers.csv')
dados_tratados = pd.DataFrame(df)

# %%
resultado = treinamento(dados_tratados, tipo = 'Agrupamento', modo = 'Estático', nome_dataset = 'Dataset')
# Out:
# Iniciando o Treinamento de Agrupamento
#  Analisando: KMeans +
#  Analisando: KMeans + PCA
#  Analisando: KMeans + KPCA
#  Analisando: Hierárquico +
#  Analisando: Hierárquico + PCA
#  Analisando: Hierárquico + KPCA
#  Analisando: DBSCAN +
#  Analisando: DBSCAN + PCA
#  Analisando: DBSCAN + KPCA
#  Analisando: MeanShift +
#  Analisando: MeanShift + PCA
#  Analisando: MeanShift + KPCA
# Analisando: KModes + Dados mistos
# Analisando: KPrototype + Dados mistos
#                       Modelo      Tipo  Clusters  Silhouette  \
# 0           MeanShift + KPCA  Numérico         3      0.5101
# 1         Hierárquico + KPCA  Numérico         5      0.5063
# 2              KMeans + KPCA  Numérico         5      0.4764
# 3               KMeans + PCA  Numérico         5      0.4061
# 4          Hierárquico + PCA  Numérico         5      0.3942
# 5                  KMeans +   Numérico         5      0.3762
# 6  KPrototype + Dados mistos     Misto         5      0.3440
# ...

# %%
resultado_otimizado = otimizar(resultado)
# Out:
# Nenhum modelo salvo anteriormente, Selecionando o top 3 melhores modelos para otimizar
# Modelos Selecionados para Otimizção:
# MeanShift + KPCA
# Hierárquico + KPCA
# KMeans + KPCA
# Quantos Trials Deseja Rodar ? (Enter para usar 50):
# [W 2026-09-07 18:40:42,731] Trial 0 failed with parameters: {} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\ga76\OneDrive\Área de Trabalho\Machine Learning Curso\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "c:\Users\ga76\OneDrive\Área de Trabalho\Machine Learning Curso\notebooks\Agrupamento\../..\src\nao_supervisionado\agrupamento\otimizacao_agrupamento.py", line 35, in objetivo
#     origem_dados = modelos_cat_dict
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
analise = relatorio(resultado)
# Out:
#                Modelo  Silhouette
# 0    MeanShift + KPCA      0.5101
# 1       KMeans + KPCA      0.4762
# 2  Hierárquico + KPCA      0.4082
# Deseja Gerar um Relatório para um Modelo? (s/n)
# Digite o Número do Modelo que Deseja Analisar (0 a 2):
# Gerando o Relatório para o modelo: MeanShift + KPCA
# Ignorando CustomerID, pois parece ser uma coluna de ID
# --------------------------------------------------

# %%
modelo = salvar(resultado)
# Out:
# Iniciando o Processo de Salvamento
# Salvar Modelo None
#                Modelo  Silhouette
# 0    MeanShift + KPCA      0.5101
# 1       KMeans + KPCA      0.4762
# 2  Hierárquico + KPCA      0.4082
# Deseja Salvar um Modelo? (s/n)
# Digite o Número do Modelo que Deseja Salvar (0 a 2):
# Colunas no modelo_escolhido:
#   Modelo: str = MeanShift + KPCA
#   Melhores Hiperparâmetros: dict = {}
#   Clusters: int64 = 3
#   Silhouette best: float64 = 0.5101
#   Silhouette: float64 = 0.5101
#   Calinski-Harabasz: float64 = 272.9534
#   Davies_Bouldin: float64 = 0.6472
# Pipeline salvo em: modelos_salvos\2026_09_07_18-21_Agrupamento_MeanShift___KPCA_Silhouette_0.5101.joblib
# Metadados salvos em: modelos_salvos\2026_09_07_18-21_Agrupamento_MeanShift___KPCA_Silhouette_0.5101_metadata.json
