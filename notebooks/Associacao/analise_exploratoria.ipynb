# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import pandas as pd
from automl import eda
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../../dataset/raw/Groceries_dataset.csv')
dados = pd.DataFrame(df)

# %%
analise = eda(dados, colunas_id = 'Member_number', categoria = 'Não Supervisionado', tipo = 'Associação', coluna_data = 'Date', modo = 'Série Temporal')
# Out:
# EDA da Série Temporal na coluna Date
# Análise exploratória
#
# 0 colunas numéricas
# []
#
# 1 colunas categóricas
# ['itemDescription']
#
# 1 colunas de tempo
# ['Date']
# Analisando as Variáveis Categóricas ao longo tempo
# Variável itemDescription
#
# Total de categorias 167
#
# Valores nulos: 0 (0.00%)
#
# Top 5 categorias mais frequentes
#
# itemDescription
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
#
# --------------------------------------------------
# itemDescription tem muitas categorias (167). Plotando apenas as 15 mais frequentes
