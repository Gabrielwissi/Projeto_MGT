# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import pandas as pd
from automl import treinamento, relatorio, salvar
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../../dataset/raw/Groceries_dataset.csv')
dados_tratados = pd.DataFrame(df)

# %%
resultado = treinamento(dados_tratados, tipo = 'Associação', modo = 'Série Temporal', nome_dataset = 'Dataset')
# Out:
# Qual o formato dos dados ?
# 1 - Lista (coluna de ID + coluna e itens)
# 2 - Tabela (colunas binárias)
#
# formato escolhido: Lista
#
# Digite a coluna de ID
#
# Nome da coluna_id: Member_number
#
# Digite a coluna de itens:
#
# Nome da coluna de itens: itemDescription
#
# Iniciando regras com o apriori
# Convertendo para o Formato Transacional
# 3016 itens frequentes encontrados.
# Sucesso: 5844 Regras Geradas em 0.3778s
#                                             antecedents  \
# 0     frozenset({whole milk, sausage, other vegetabl...
# 1     frozenset({yogurt, rolls/buns, other vegetables})
# 2                             frozenset({yogurt, curd})
# 3          frozenset({whole milk, sausage, rolls/buns})
# 4           frozenset({yogurt, whole milk, rolls/buns})
# ...                                                 ...
# 5839  frozenset({long life bakery product, other veg...
# 5840             frozenset({packaged fruit/vegetables})
# ...

# %%
resultado_2 = treinamento(dados_tratados, itens_ignorar = 'whole milk', tipo = 'Associação', modo = 'Série Temporal', nome_dataset = 'Dataset')
# Out:
# Qual o formato dos dados ?
# 1 - Lista (coluna de ID + coluna e itens)
# 2 - Tabela (colunas binárias)
# Nome da coluna_id:
# Nome da coluna de itens
# Iniciando regras com o apriori
# Convertendo para o Formato Transacional
# Ignorando as colunas: ['whole milk']
# 2163 itens frequentes encontrados.
# Sucesso: 3184 Regras Geradas em 0.3413s
#                                             antecedents  \
# 0                       frozenset({sausage, pip fruit})
# 1                   frozenset({sausage, bottled water})
# 2                         frozenset({rolls/buns, beef})
# 3     frozenset({other vegetables, rolls/buns, root ...
# 4                      frozenset({rolls/buns, sausage})
# ...                                                 ...
# 3179                             frozenset({margarine})
# 3180             frozenset({packaged fruit/vegetables})
# 3181                                 frozenset({herbs})
# 3182                                 frozenset({herbs})
# ...

# %%
analise = relatorio(resultado)
# Out:
# Gerando o Relatório para as regras de associação

# %%
modelo = salvar(resultado)
# Out:
# Iniciando o Processo de Salvamento
# Pipeline salvo em: modelos_salvos\2026_08_07_16-32_associacao_apriori_pipeline.joblib
# Pipeline salvo em: modelos_salvos\2026_08_07_16-32_associacao_apriori_pipeline.joblib
# Regras salvas em: modelos_salvos\2026_08_07_16-32_associacao_apriori_regras.csv
# Metadados salvos em: modelos_salvos\2026_08_07_16-32_associacao_apriori_metadata.json
